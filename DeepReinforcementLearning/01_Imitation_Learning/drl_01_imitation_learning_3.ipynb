# %% [markdown]
# Authors: Hofmarcher
#
# Date: 20-03-2023
#
# ---
#
# This file is part of the "Deep Reinforcement Learning" lecture material. The following copyright statement applies to all code within this file.
#
# Copyright statement:
# This material, no matter whether in printed or electronic form, may be used for personal and non-commercial educational use only. Any reproduction of this manuscript, no matter whether as a whole or in parts, no matter whether in printed or in electronic form, requires explicit prior acceptance of the authors.

# %% [markdown]
# ## Enable GPU Acceleration

# %% [markdown]
# ---
# Before you start exploring this notebook make sure that GPU support is enabled.
# To enable the GPU backend for your notebook, go to **Edit** → **Notebook Settings** and set **Hardware accelerator** to **GPU**.
#
# ---

# %%
## Sources:
# https://www.geeksforgeeks.org/reinforce-algorithm/

# Model: https://github.com/kvgarimella/dagger/blob/main/model.py
#

# %% [markdown]
# # Imports

# %% [markdown]
# Install Gymnasium and dependencies to render the environments

# %%
# !apt-get update
# !apt-get install -y swig python3-numpy python3-dev cmake zlib1g-dev libjpeg-dev xvfb ffmpeg xorg-dev python3-opengl libboost-all-dev libsdl2-dev
# !pip install gymnasium==0.29.0 gymnasium[box2d] pyvirtualdisplay imageio-ffmpeg moviepy==1.0.3
# !pip install onnx onnx2pytorch==0.4.1
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,381 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,788 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,045 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,049 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,538 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [55.7 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,685 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,737 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [47.7 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,892 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,239 kB]
# Fetched 29.9 MB in 7s (3,997 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu10).
# libjpeg-dev set to manually installed.
# libboost-all-dev is already the newest version (1.74.0.3ubuntu7).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# python3-dev is already the newest version (3.10.6-1~22.04.1).
# python3-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   freeglut3 gir1.2-ibus-1.0 libdbus-1-dev libdecor-0-dev libdmx-dev libdmx1 libdrm-dev libegl-dev
#   libegl1-mesa-dev libfontenc-dev libfontenc1 libfs-dev libfs6 libgbm-dev libgl-dev libgles-dev
#   libgles1 libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libibus-1.0-5
#   libibus-1.0-dev libopengl-dev libpciaccess-dev libpulse-dev libpulse-mainloop-glib0 libsndio-dev
#   libudev-dev libwayland-bin libwayland-dev libxaw7-dev libxcomposite-dev libxcursor-dev
#   libxcvt-dev libxcvt0 libxdamage-dev libxfixes-dev libxfont-dev libxfont2 libxi-dev
#   libxinerama-dev libxkbcommon-dev libxkbfile-dev libxkbfile1 libxmu-dev libxmu-headers libxmuu-dev
#   libxpm-dev libxrandr-dev libxres-dev libxres1 libxt-dev libxtst-dev libxtst6 libxv-dev
#   libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1 libxxf86vm-dev mesa-common-dev swig4.0
#   x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils xserver-common xserver-xorg-dev
# Suggested packages:
#   libwayland-doc libxaw-doc libxt-doc python-numpy-doc python3-pytest libgle3 swig-doc
#   swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   freeglut3 gir1.2-ibus-1.0 libdbus-1-dev libdecor-0-dev libdmx-dev libdmx1 libdrm-dev libegl-dev
#   libegl1-mesa-dev libfontenc-dev libfontenc1 libfs-dev libfs6 libgbm-dev libgl-dev libgles-dev
#   libgles1 libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libibus-1.0-5
#   libibus-1.0-dev libopengl-dev libpciaccess-dev libpulse-dev libpulse-mainloop-glib0 libsdl2-dev
#   libsndio-dev libudev-dev libwayland-bin libwayland-dev libxaw7-dev libxcomposite-dev
#   libxcursor-dev libxcvt-dev libxcvt0 libxdamage-dev libxfixes-dev libxfont-dev libxfont2 libxi-dev
#   libxinerama-dev libxkbcommon-dev libxkbfile-dev libxkbfile1 libxmu-dev libxmu-headers libxmuu-dev
#   libxpm-dev libxrandr-dev libxres-dev libxres1 libxt-dev libxtst-dev libxtst6 libxv-dev
#   libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1 libxxf86vm-dev mesa-common-dev python3-numpy
#   python3-opengl swig swig4.0 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils xorg-dev
#   xserver-common xserver-xorg-dev xvfb
# 0 upgraded, 76 newly installed, 0 to remove and 41 not upgraded.
# Need to get 20.7 MB of archives.
# After this operation, 76.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libibus-1.0-5 amd64 1.5.26-4 [183 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-ibus-1.0 amd64 1.5.26-4 [88.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdbus-1-dev amd64 1.12.20-2ubuntu4.1 [188 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-bin amd64 1.20.0-1ubuntu0.1 [20.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-dev amd64 1.20.0-1ubuntu0.1 [69.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-dev amd64 0.1.0-3build1 [5,544 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdmx1 amd64 1:1.1.4-2build2 [9,372 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdmx-dev amd64 1:1.1.4-2build2 [33.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess-dev amd64 0.16-3 [21.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-dev amd64 2.4.113-2~ubuntu0.22.04.1 [292 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [11.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc-dev amd64 1:1.1.4-1build3 [15.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfs6 amd64 2:1.0.8-1build2 [22.9 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfs-dev amd64 2:1.0.8-1build2 [29.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgbm-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [9,542 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libibus-1.0-dev amd64 1.5.26-4 [185 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse-mainloop-glib0 amd64 1:15.99.1+dfsg1-1ubuntu2.2 [12.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse-dev amd64 1:15.99.1+dfsg1-1ubuntu2.2 [75.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsndio-dev amd64 1.8.1-1.1 [17.8 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev-dev amd64 249.11-0ubuntu3.12 [20.7 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor-dev amd64 1:1.2.0-2build4 [28.2 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi-dev amd64 2:1.8-1build1 [193 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxinerama-dev amd64 2:1.1.4-3 [8,104 B]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-dev amd64 1.4.0-1 [54.9 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr-dev amd64 2:1.5.2-1build1 [26.7 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxv-dev amd64 2:1.0.11-1build2 [33.4 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86vm-dev amd64 1:1.1.4-1build3 [13.9 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsdl2-dev amd64 2.0.20+dfsg-2ubuntu1.22.04.1 [1,767 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu-headers all 2:1.1.3-3 [54.1 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu-dev amd64 2:1.1.3-3 [54.6 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxpm-dev amd64 1:3.5.12-1ubuntu0.22.04.2 [90.7 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxaw7-dev amd64 2:1.0.14-1 [253 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite-dev amd64 1:0.4.5-1build2 [9,326 B]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt-dev amd64 0.1.1-3 [3,242 B]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxdamage-dev amd64 1:1.1.5-2build2 [5,264 B]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont-dev amd64 1:2.0.5-1build1 [128 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile-dev amd64 1:1.1.0-1build3 [85.0 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmuu-dev amd64 2:1.1.3-3 [7,926 B]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxres1 amd64 2:1.2.1-1 [7,776 B]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxres-dev amd64 2:1.2.1-1 [8,538 B]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst-dev amd64 2:1.2.3-1build4 [16.3 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxvmc1 amd64 2:1.0.12-2build2 [13.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxvmc-dev amd64 2:1.0.12-2build2 [24.2 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga-dev amd64 2:1.1.5-0ubuntu3 [16.5 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-common-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [2,208 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-opengl all 3.1.5+dfsg-1 [605 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-dev amd64 2:21.1.4-2ubuntu1.7~22.04.13 [204 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 xorg-dev all 1:7.7+23ubuntu2 [4,262 B]
# Get:75 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.13 [29.1 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.13 [863 kB]
# Fetched 20.7 MB in 3s (5,953 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package freeglut3:amd64.
# (Reading database ... 126209 files and directories currently installed.)
# Preparing to unpack .../00-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../01-libibus-1.0-5_1.5.26-4_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.26-4) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../02-gir1.2-ibus-1.0_1.5.26-4_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.26-4) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../03-libdbus-1-dev_1.12.20-2ubuntu4.1_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.20-2ubuntu4.1) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../04-libwayland-bin_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../05-libwayland-dev_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libdecor-0-dev:amd64.
# Preparing to unpack .../06-libdecor-0-dev_0.1.0-3build1_amd64.deb ...
# Unpacking libdecor-0-dev:amd64 (0.1.0-3build1) ...
# Selecting previously unselected package libdmx1:amd64.
# Preparing to unpack .../07-libdmx1_1%3a1.1.4-2build2_amd64.deb ...
# Unpacking libdmx1:amd64 (1:1.1.4-2build2) ...
# Selecting previously unselected package libdmx-dev:amd64.
# Preparing to unpack .../08-libdmx-dev_1%3a1.1.4-2build2_amd64.deb ...
# Unpacking libdmx-dev:amd64 (1:1.1.4-2build2) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../09-libpciaccess-dev_0.16-3_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-3) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../10-libdrm-dev_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../11-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../12-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../13-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../14-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../15-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../16-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../17-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../18-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../19-libegl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../20-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libfontenc-dev:amd64.
# Preparing to unpack .../21-libfontenc-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libfs6:amd64.
# Preparing to unpack .../22-libfs6_2%3a1.0.8-1build2_amd64.deb ...
# Unpacking libfs6:amd64 (2:1.0.8-1build2) ...
# Selecting previously unselected package libfs-dev:amd64.
# Preparing to unpack .../23-libfs-dev_2%3a1.0.8-1build2_amd64.deb ...
# Unpacking libfs-dev:amd64 (2:1.0.8-1build2) ...
# Selecting previously unselected package libgbm-dev:amd64.
# Preparing to unpack .../24-libgbm-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgbm-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../25-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../26-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../27-libibus-1.0-dev_1.5.26-4_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.26-4) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../28-libpulse-mainloop-glib0_1%3a15.99.1+dfsg1-1ubuntu2.2_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../29-libpulse-dev_1%3a15.99.1+dfsg1-1ubuntu2.2_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../30-libsndio-dev_1.8.1-1.1_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.8.1-1.1) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../31-libudev-dev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev-dev:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../32-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../33-libxcursor-dev_1%3a1.2.0-2build4_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../34-libxi-dev_2%3a1.8-1build1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.8-1build1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../35-libxinerama-dev_2%3a1.1.4-3_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-3) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../36-libxkbcommon-dev_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../37-libxrandr-dev_2%3a1.5.2-1build1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../38-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../39-libxv-dev_2%3a1.0.11-1build2_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1build2) ...
# Selecting previously unselected package libxxf86vm-dev:amd64.
# Preparing to unpack .../40-libxxf86vm-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libxxf86vm-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../41-libsdl2-dev_2.0.20+dfsg-2ubuntu1.22.04.1_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../42-libxmu-headers_2%3a1.1.3-3_all.deb ...
# Unpacking libxmu-headers (2:1.1.3-3) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../43-libxmu-dev_2%3a1.1.3-3_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.3-3) ...
# Selecting previously unselected package libxpm-dev:amd64.
# Preparing to unpack .../44-libxpm-dev_1%3a3.5.12-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libxpm-dev:amd64 (1:3.5.12-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libxaw7-dev:amd64.
# Preparing to unpack .../45-libxaw7-dev_2%3a1.0.14-1_amd64.deb ...
# Unpacking libxaw7-dev:amd64 (2:1.0.14-1) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../46-libxcomposite-dev_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../47-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxcvt-dev:amd64.
# Preparing to unpack .../48-libxcvt-dev_0.1.1-3_amd64.deb ...
# Unpacking libxcvt-dev:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxdamage-dev:amd64.
# Preparing to unpack .../49-libxdamage-dev_1%3a1.1.5-2build2_amd64.deb ...
# Unpacking libxdamage-dev:amd64 (1:1.1.5-2build2) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../50-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxfont-dev.
# Preparing to unpack .../51-libxfont-dev_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont-dev (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../52-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxkbfile-dev:amd64.
# Preparing to unpack .../53-libxkbfile-dev_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxmuu-dev:amd64.
# Preparing to unpack .../54-libxmuu-dev_2%3a1.1.3-3_amd64.deb ...
# Unpacking libxmuu-dev:amd64 (2:1.1.3-3) ...
# Selecting previously unselected package libxres1:amd64.
# Preparing to unpack .../55-libxres1_2%3a1.2.1-1_amd64.deb ...
# Unpacking libxres1:amd64 (2:1.2.1-1) ...
# Selecting previously unselected package libxres-dev:amd64.
# Preparing to unpack .../56-libxres-dev_2%3a1.2.1-1_amd64.deb ...
# Unpacking libxres-dev:amd64 (2:1.2.1-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../57-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxtst-dev:amd64.
# Preparing to unpack .../58-libxtst-dev_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst-dev:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxvmc1:amd64.
# Preparing to unpack .../59-libxvmc1_2%3a1.0.12-2build2_amd64.deb ...
# Unpacking libxvmc1:amd64 (2:1.0.12-2build2) ...
# Selecting previously unselected package libxvmc-dev:amd64.
# Preparing to unpack .../60-libxvmc-dev_2%3a1.0.12-2build2_amd64.deb ...
# Unpacking libxvmc-dev:amd64 (2:1.0.12-2build2) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../61-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package libxxf86dga-dev:amd64.
# Preparing to unpack .../62-libxxf86dga-dev_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga-dev:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../63-mesa-common-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../64-python3-numpy_1%3a1.21.5-1ubuntu22.04.1_amd64.deb ...
# Unpacking python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Selecting previously unselected package python3-opengl.
# Preparing to unpack .../65-python3-opengl_3.1.5+dfsg-1_all.deb ...
# Unpacking python3-opengl (3.1.5+dfsg-1) ...
# Selecting previously unselected package swig4.0.
# Preparing to unpack .../66-swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../67-swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../68-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../69-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../70-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../71-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-xorg-dev.
# Preparing to unpack .../72-xserver-xorg-dev_2%3a21.1.4-2ubuntu1.7~22.04.13_amd64.deb ...
# Unpacking xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Selecting previously unselected package xorg-dev.
# Preparing to unpack .../73-xorg-dev_1%3a7.7+23ubuntu2_all.deb ...
# Unpacking xorg-dev (1:7.7+23ubuntu2) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../74-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.13_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../75-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.13_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Setting up libxmu-headers (2:1.1.3-3) ...
# Setting up libsndio-dev:amd64 (1.8.1-1.1) ...
# Setting up libpciaccess-dev:amd64 (0.16-3) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1build3) ...
# Setting up libxkbcommon-dev:amd64 (1.4.0-1) ...
# Setting up libibus-1.0-5:amd64 (1.5.26-4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libxvmc1:amd64 (2:1.0.12-2build2) ...
# Setting up libgbm-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1build2) ...
# Setting up libwayland-bin (1.20.0-1ubuntu0.1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Setting up libdbus-1-dev:amd64 (1.12.20-2ubuntu4.1) ...
# Setting up libdmx1:amd64 (1:1.1.4-2build2) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libdmx-dev:amd64 (1:1.1.4-2build2) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxpm-dev:amd64 (1:3.5.12-1ubuntu0.22.04.2) ...
# Setting up libudev-dev:amd64 (249.11-0ubuntu3.12) ...
# Setting up libxinerama-dev:amd64 (2:1.1.4-3) ...
# Setting up python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Setting up libpulse-dev:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up libfs6:amd64 (2:1.0.8-1build2) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up libxi-dev:amd64 (2:1.8-1build1) ...
# Setting up libxmuu-dev:amd64 (2:1.1.3-3) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.26-4) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libxres1:amd64 (2:1.2.1-1) ...
# Setting up libxvmc-dev:amd64 (2:1.0.12-2build2) ...
# Setting up libxtst-dev:amd64 (2:1.2.3-1build4) ...
# Setting up libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Setting up libxdamage-dev:amd64 (1:1.1.5-2build2) ...
# Setting up libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Setting up libxcvt-dev:amd64 (0.1.1-3) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.5-1build2) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up libxxf86dga-dev:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Setting up python3-opengl (3.1.5+dfsg-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.3-3) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libibus-1.0-dev:amd64 (1.5.26-4) ...
# Setting up libdecor-0-dev:amd64 (0.1.0-3build1) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libfs-dev:amd64 (2:1.0.8-1build2) ...
# Setting up libxaw7-dev:amd64 (2:1.0.14-1) ...
# Setting up libxres-dev:amd64 (2:1.2.1-1) ...
# Setting up mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Setting up libxfont-dev (1:2.0.5-1build1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libsdl2-dev:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Setting up xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Setting up xorg-dev (1:7.7+23ubuntu2) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Collecting gymnasium==0.29.0
#   Downloading gymnasium-0.29.0-py3-none-any.whl.metadata (10 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (0.6.0)
# Requirement already satisfied: moviepy==1.0.3 in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.0) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.0) (0.0.4)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy==1.0.3) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy==1.0.3) (2.37.0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy==1.0.3) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy==1.0.3) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy==1.0.3) (0.1.10)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio<3.0,>=2.5->moviepy==1.0.3) (11.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3) (2025.1.31)
# Downloading gymnasium-0.29.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.8/953.8 kB 42.3 MB/s eta 0:00:00
# Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 70.9 MB/s eta 0:00:00
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2351176 sha256=7eaa547bf78f58616350703f31798dca00d8ef4434aaff85634e98788eebb029
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: swig, pyvirtualdisplay, box2d-py, gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.1.1
#     Uninstalling gymnasium-1.1.1:
#       Successfully uninstalled gymnasium-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# Successfully installed box2d-py-2.3.5 gymnasium-0.29.0 pyvirtualdisplay-3.0 swig-4.3.0
# Collecting onnx
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnx2pytorch==0.4.1
#   Downloading onnx2pytorch-0.4.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from onnx2pytorch==0.4.1) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from onnx2pytorch==0.4.1) (0.21.0+cu124)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx) (5.29.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.4.0->onnx2pytorch==0.4.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->onnx2pytorch==0.4.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.4.0->onnx2pytorch==0.4.1) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.9.0->onnx2pytorch==0.4.1) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.4.0->onnx2pytorch==0.4.1) (3.0.2)
# Downloading onnx2pytorch-0.4.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.4 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 74.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.1 MB/s eta 0:00:00
# Installing collected packages: onnx, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, onnx2pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnx-1.17.0 onnx2pytorch-0.4.1

# %%
# %matplotlib inline

# Auxiliary Python imports
import os
import math
import io
import base64
import random
import shutil
from time import time, strftime
from glob import glob
from tqdm import tqdm
import numpy as np
import torch.nn.functional as F

# Pytorch
import torch
import torch.nn as nn
from torch.distributions.categorical import Categorical
import onnx
from onnx2pytorch import ConvertModel

# Environment import and set logger level to display error only
import gymnasium as gym
from gymnasium.spaces import Box
from gymnasium import logger as gymlogger
from gymnasium.wrappers import RecordVideo
gymlogger.set_level(gym.logger.ERROR)

# Plotting and notebook imports
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML, clear_output
from IPython import display

# %% [markdown]
# # Select device for training

# %% [markdown]
# By default we train on GPU if one is available, otherwise we fall back to the CPU.
# If you want to always use the CPU change accordingly.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: " + str(device))
# Out:
# Device: cuda

# %% [markdown]
# # Setup Google Drive mount to store your results

# %%
use_google_drive = True
if use_google_drive:
    from google.colab import drive
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Download Dataset and Expert model

# %%
# Download training and validation datasets
# !wget --no-check-certificate 'https://cloud.ml.jku.at/s/citYJKPgmAGrHGy/download' -O expert.onnx
# !wget --no-check-certificate 'https://cloud.ml.jku.at/s/yJ2ZsfqTos3Jn9y/download' -O train.zip
# !wget --no-check-certificate 'https://cloud.ml.jku.at/s/3DxHLiqxTddepp8/download' -O val.zip

# Unzip datasets
# !unzip -q -o train.zip
# !unzip -q -o val.zip
# Out:
# --2025-03-31 13:42:23--  https://cloud.ml.jku.at/s/citYJKPgmAGrHGy/download
# Resolving cloud.ml.jku.at (cloud.ml.jku.at)... 140.78.90.41
# Connecting to cloud.ml.jku.at (cloud.ml.jku.at)|140.78.90.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6747975 (6.4M) [application/octet-stream]
# Saving to: ‘expert.onnx’
#
# expert.onnx         100%[===================>]   6.43M   863KB/s    in 11s
#
# 2025-03-31 13:42:35 (624 KB/s) - ‘expert.onnx’ saved [6747975/6747975]
#
# --2025-03-31 13:42:35--  https://cloud.ml.jku.at/s/yJ2ZsfqTos3Jn9y/download
# Resolving cloud.ml.jku.at (cloud.ml.jku.at)... 140.78.90.41
# Connecting to cloud.ml.jku.at (cloud.ml.jku.at)|140.78.90.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85373838 (81M) [application/zip]
# Saving to: ‘train.zip’
#
# train.zip           100%[===================>]  81.42M  19.0MB/s    in 5.5s
#
# 2025-03-31 13:42:41 (14.8 MB/s) - ‘train.zip’ saved [85373838/85373838]
#
# --2025-03-31 13:42:41--  https://cloud.ml.jku.at/s/3DxHLiqxTddepp8/download
# Resolving cloud.ml.jku.at (cloud.ml.jku.at)... 140.78.90.41
# Connecting to cloud.ml.jku.at (cloud.ml.jku.at)|140.78.90.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16290406 (16M) [application/zip]
# Saving to: ‘val.zip’
#
# val.zip             100%[===================>]  15.54M  6.58MB/s    in 2.4s
#
# 2025-03-31 13:42:44 (6.58 MB/s) - ‘val.zip’ saved [16290406/16290406]

# %% [markdown]
# # Auxiliary Methods

# %% [markdown]
# The following cell contains classes and functions to provide some functionality for logging, plotting and exporting your model in the format required by the submission server.
# You are free to use your own logging framework if you wish (such as tensorboard or Weights & Biases).
# The logger is a very simple implementation of a CSV-file based logger.
# Additionally it creates a folder for each run with subfolders for model files, logs and videos.

# %%
class Logger():
    def __init__(self, logdir, params=None):
        self.basepath = os.path.join(logdir, strftime("%Y-%m-%dT%H-%M-%S"))
        os.makedirs(self.basepath, exist_ok=True)
        os.makedirs(self.log_dir, exist_ok=True)
        if params is not None and os.path.exists(params):
            shutil.copyfile(params, os.path.join(self.basepath, "params.pkl"))
        self.log_dict = {}
        self.dump_idx = {}

    @property
    def param_file(self):
        return os.path.join(self.basepath, "params.pkl")

    @property
    def onnx_file(self):
        return os.path.join(self.basepath, "model.onnx")

    @property
    def video_dir(self):
        return os.path.join(self.basepath, "videos")

    @property
    def log_dir(self):
        return os.path.join(self.basepath, "logs")

    def log(self, name, value):
        if name not in self.log_dict:
            self.log_dict[name] = []
            self.dump_idx[name] = -1
        self.log_dict[name].append((len(self.log_dict[name]), time(), value))

    def get_values(self, name):
        if name in self.log_dict:
            return [x[2] for x in self.log_dict[name]]
        return None

    def dump(self):
        for name, rows in self.log_dict.items():
            with open(os.path.join(self.log_dir, name + ".log"), "a") as f:
                for i, row in enumerate(rows):
                    if i > self.dump_idx[name]:
                        f.write(",".join([str(x) for x in row]) + "\n")
                        self.dump_idx[name] = i


def plot_metrics(logger):
    train_loss  = logger.get_values("training_loss")
    train_entropy  = logger.get_values("training_entropy")
    val_loss = logger.get_values("validation_loss")
    val_acc = logger.get_values("validation_accuracy")

    fig = plt.figure(figsize=(15,5))
    ax1 = fig.add_subplot(131, label="train")
    ax2 = fig.add_subplot(131, label="val",frame_on=False)
    ax4 = fig.add_subplot(132, label="entropy")
    ax3 = fig.add_subplot(133, label="acc")

    ax1.plot(train_loss, color="C0")
    ax1.set_ylabel("Loss")
    ax1.set_xlabel("Update (Training)", color="C0")
    ax1.xaxis.grid(False)
    ax1.set_ylim((0,4))

    ax2.plot(val_loss, color="C1")
    ax2.xaxis.tick_top()
    ax2.yaxis.tick_right()
    ax2.set_xlabel('Epoch (Validation)', color="C1")
    ax2.xaxis.set_label_position('top')
    ax2.xaxis.grid(False)
    ax2.get_yaxis().set_visible(False)
    ax2.set_ylim((0,4))

    ax4.plot(train_entropy, color="C3")
    ax4.set_xlabel('Update (Training)', color="black")
    ax4.set_ylabel("Entropy", color="C3")
    ax4.tick_params(axis='x', colors="black")
    ax4.tick_params(axis='y', colors="black")
    ax4.xaxis.grid(False)

    ax3.plot(val_acc, color="C2")
    ax3.set_xlabel("Epoch (Validation)", color="black")
    ax3.set_ylabel("Accuracy", color="C2")
    ax3.tick_params(axis='x', colors="black")
    ax3.tick_params(axis='y', colors="black")
    ax3.xaxis.grid(False)
    ax3.set_ylim((0,1))

    fig.tight_layout(pad=2.0)
    plt.show()

"""
Utility functions to enable video recording of gym environment and displaying it
"""
def show_video(video_dir):
    mp4list = glob(f'{video_dir}/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        display.display(HTML(data='''<video alt="test" autoplay
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                 </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

def save_as_onnx(torch_model, sample_input, model_path):
    torch.onnx.export(torch_model,             # model being run
                    sample_input,              # model input (or a tuple for multiple inputs)
                    f=model_path,              # where to save the model (can be a file or file-like object)
                    export_params=True,        # store the trained parameter weights inside the model file
                    opset_version=17,          # the ONNX version to export the model to - see https://github.com/microsoft/onnxruntime/blob/master/docs/Versioning.md
                    do_constant_folding=True,  # whether to execute constant folding for optimization
                    )

# %% [markdown]
# # Dataset

# %% [markdown]
# Use this dataset class to load the provided demonstrations. Furthermore, this dataset has functionality to add new samples to the dataset which you will need for implementing the DAgger algorithm.

# %%
class DemonstrationDataset(torch.utils.data.Dataset):
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.files = sorted(glob(f"{data_dir}/*.npz"))

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        data = np.load(self.files[idx])
        state = data["state"][np.newaxis, ...].astype(np.float32)
        action = data["action"]
        return state / 255.0, action.item()

    def append(self, states, actions):
        offset = len(self) + 1
        for i in range(len(states)):
            filename = f"{self.data_dir}/{offset+i:06}.npz"
            np.savez_compressed(filename, state=states[i], action=actions[i].astype(np.int32))
            self.files.append(filename)

# %% [markdown]
# # Inspect data

# %% [markdown]
# It is always a good idea to take a look at the data when you start working with a new dataset. Feel free to investigate the dataset further on your own.

# %%
# Action Statistics
dataset = DemonstrationDataset("train")
print("Number of samples: {}".format(len(dataset)));
# Out:
# Number of samples: 49538

# %%
# Action mapping from gymnasium.farama.org
action_mapping = {
    0: "do nothing",
    1: "steer left",
    2: "steer right",
    3: "gas",
    4: "brake"
}

# Visualize random frames
idx = np.random.randint(len(dataset))
state, action = dataset[idx]
# store a single frame as we need it later for exporting an ONNX model (it needs a sample of the input for the export)
sample_state = torch.Tensor(state).unsqueeze(0).to(device)
# Display the sample
print(f"Action: {action_mapping[action]}")
plt.axis("off")
plt.imshow(state[0]);
# Out:
# Action: gas

# %%
# release memory
del dataset

# %% [markdown]
# # Define Policy Network

# %% [markdown]
# You need to design a neural network architecture that is capable of mapping a state to an action.
# The input is a single image with the following properties:
# - Resolution of 84x84 pixels
# - Grayscale (meaning a single channel as opposed to three channels of an RGB image)
# - The values of each pixel should be between 0 and 1
#
# The output of the network should be one unit per possible action, as our environment has 5 actions that results in 5 output units.
# Your network must implement the forward function in order to be compatible with the evaluation script.

# %%
class PolicyNetwork(nn.Module):
    def __init__(self, n_units_out):
        super(PolicyNetwork, self).__init__()
        ######################
        ### YOUR CODE HERE ###
        ######################

        # Define a network with three conv layers and two linear layers
        self.net = nn.Sequential(
             nn.Conv2d(1, 4, kernel_size=5),
             nn.BatchNorm2d(4),
             nn.MaxPool2d(2),
             nn.ReLU(),

             nn.Conv2d(4, 8, 5),
             nn.BatchNorm2d(8),
             nn.MaxPool2d(2),
             nn.ReLU(),

             nn.Conv2d(8, 16, 6),
             nn.BatchNorm2d(16),
             nn.MaxPool2d(2),
             nn.ReLU(),

             nn.Flatten(),

             nn.Linear(576, 64),
             nn.ReLU(),
             nn.Linear(64, 16),
             nn.ReLU(),
             nn.Linear(16, n_units_out)

        )

    def forward(self, x):
        ######################
        ### YOUR CODE HERE ###
        ######################
        return self.net(x)

# %% [markdown]
# # Train behavioral cloning policy

# %% [markdown]
# Now that you have a Dataset and a network you need to train your network.
# With behavioral cloning we want to imitate the behavior of the agent that produced the demonstration dataset as close as possible.
# This is basically supervised learning, where you want to minimize the loss of your network on the training and validation sets.
#
# Some tips as to what you need to implement:
# - choose the appropriate loss function (think on which kind of problem you are solving)
# - choose an optimizer and its hyper-parameters
# - optional: use a learning-rate scheduler
# - don't forget to evaluate your network on the validation set
# - store your model and training progress often so you don't loose progress if your program crashes
#
# In case you use the provided Logger:
# - `logger.log("training_loss", <loss-value>)` to log a particular value
# - `logger.dump()` to write the current logs to a log file (e.g. after every episode)
# - `logger.log_dir`, `logger.param_file`, `logger.onnx_file`, `logger.video_dir` point to files or directories you can use to save files
# - you might want to specify your google drive folder as a logdir in order to automatically sync your results
# - if you log the metrics specified in the `plot_metrics` function you can use it to visualize your training progress (or take it as a template to plot your own metrics)

# %%
# choose the batchsize for training
batch_size = 64

# Datasets
train_set = DemonstrationDataset("train")
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, num_workers=2, shuffle=True, drop_last=False, pin_memory=True)
val_set = DemonstrationDataset("val")
val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, num_workers=2, shuffle=False, drop_last=False, pin_memory=True)

# Specify the google drive mount here if you want to store logs and weights there (and set it up earlier)
# You can also choose to use a different logging framework such as tensorboard (not recommended on Colab) or Weights & Biases (highly recommended)
logger = Logger("data/logdir")
print("Saving state to {}".format(logger.basepath))

# Network
model = PolicyNetwork(n_units_out=5)
model = model.to(device)
num_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Trainable Parameters: {}".format(num_trainable_params))

######################
### YOUR CODE HERE ###
######################
# Implement your training and evaluation loop
# feel free to define your own functions for training and evaluation
LR = 1e-5
optimizer = torch.optim.AdamW(model.parameters(), lr = LR)
lossfct = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
epochs = 15

# initialize weights
def init_weights(model):
    if type(model) == nn.Linear:
        torch.nn.init.kaiming_normal_(model.weight, nonlinearity='relu')
        model.bias.data.fill_(0.01)
model.apply(init_weights)

def train_network():
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        correct = 0
        total = 0

        for states, actions in train_loader:
            states = states.to(device)
            actions = actions.to(device)

            optimizer.zero_grad()
            prediction = model.forward(states)
            loss = lossfct(prediction, actions)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, pred = prediction.max(1)
            correct += (pred == actions).sum().item()
            total += actions.size(0)

        train_loss = total_loss / len(train_loader)
        train_accuracy = correct / total
        logger.log('training_loss', train_loss)
        logger.log('training_entropy', train_accuracy)

        ## Evaluation
        model.eval()
        val_loss = 0
        correct = 0
        total = 0
        with torch.no_grad():
            for states, actions in val_loader:
                states = states.to(device)
                actions = actions.to(device)

                prediction = model.forward(states)
                res = lossfct(prediction, actions)

                val_loss += res.item()
                _, pred = prediction.max(1)
                correct += (pred == actions).sum().item()
                total += actions.size(0)

        val_loss = val_loss / len(val_loader)
        val_accuracy = correct / total
        logger.log('validation_loss', val_loss)
        logger.log('validation_accuracy', val_accuracy)
        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Acc: {val_accuracy:.4f}")
        logger.dump()
        scheduler.step()

# Train the network
train_network()
# Plot the metrics
plot_metrics(logger)

# If you want to export your model as an ONNX file use the following code as template
# If you use the provided logger you can use this directly
save_as_onnx(model, sample_state, logger.onnx_file)
# Out:
# Saving state to data/logdir/2025-03-31T13-43-17
# Trainable Parameters: 43645
# Epoch [1/15], Train Loss: 1.0932, Val Loss: 0.9210, Train Acc: 0.6313, Val Acc: 0.6786
# Epoch [2/15], Train Loss: 0.8459, Val Loss: 0.8363, Train Acc: 0.7039, Val Acc: 0.6944
# Epoch [3/15], Train Loss: 0.8009, Val Loss: 0.8106, Train Acc: 0.7120, Val Acc: 0.7005
# Epoch [4/15], Train Loss: 0.7844, Val Loss: 0.8002, Train Acc: 0.7143, Val Acc: 0.7030
# Epoch [5/15], Train Loss: 0.7773, Val Loss: 0.7950, Train Acc: 0.7164, Val Acc: 0.7038
# Epoch [6/15], Train Loss: 0.7716, Val Loss: 0.7928, Train Acc: 0.7167, Val Acc: 0.7051
# Epoch [7/15], Train Loss: 0.7707, Val Loss: 0.7908, Train Acc: 0.7177, Val Acc: 0.7040
# Epoch [8/15], Train Loss: 0.7689, Val Loss: 0.7904, Train Acc: 0.7184, Val Acc: 0.7037
# Epoch [9/15], Train Loss: 0.7661, Val Loss: 0.7889, Train Acc: 0.7195, Val Acc: 0.7034
# Epoch [10/15], Train Loss: 0.7662, Val Loss: 0.7887, Train Acc: 0.7190, Val Acc: 0.7044
# Epoch [11/15], Train Loss: 0.7648, Val Loss: 0.7877, Train Acc: 0.7198, Val Acc: 0.7037
# Epoch [12/15], Train Loss: 0.7641, Val Loss: 0.7876, Train Acc: 0.7200, Val Acc: 0.7031
# Epoch [13/15], Train Loss: 0.7631, Val Loss: 0.7870, Train Acc: 0.7203, Val Acc: 0.7052
# Epoch [14/15], Train Loss: 0.7642, Val Loss: 0.7866, Train Acc: 0.7203, Val Acc: 0.7043
# Epoch [15/15], Train Loss: 0.7622, Val Loss: 0.7869, Train Acc: 0.7200, Val Acc: 0.7037

# %% [markdown]
# # Evaluate the agent in the real environment

# %% [markdown]
# ### Environment and Agent

# %% [markdown]
# We provide some wrappers you need in order to get the same states from the environment as in the demonstration dataset.
# Additionally the `RecordState` wrapper should be very helpful in collecting new samples for the DAgger algorithm.

# %%
class CropObservation(gym.ObservationWrapper):
    def __init__(self, env, shape):
        gym.ObservationWrapper.__init__(self, env)
        self.shape = shape
        obs_shape = self.shape + env.observation_space.shape[2:]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def observation(self, observation):
        return observation[:self.shape[0], :self.shape[1]]


class RecordState(gym.Wrapper):
    def __init__(self, env: gym.Env, reset_clean: bool = True):
        gym.Wrapper.__init__(self, env)

        assert env.render_mode is not None
        self.frame_list = []
        self.reset_clean = reset_clean

    def step(self, action, **kwargs):
        output = self.env.step(action, **kwargs)
        self.frame_list.append(output[0])
        return output

    def reset(self, *args, **kwargs):
        result = self.env.reset(*args, **kwargs)

        if self.reset_clean:
            self.frame_list = []
        self.frame_list.append(result[0])

        return result

    def render(self):
        frames = self.frame_list
        self.frame_list = []
        return frames


class Agent():
    def __init__(self, model, device):
        self.model = model
        self.device = device

    def select_action(self, state):
        with torch.no_grad():
            state = torch.Tensor(state).unsqueeze(0).to(device) / 255.0 # rescale
            logits = self.model(state)
            if type(logits) is tuple:
                logits = logits[0]
            probs = Categorical(logits=logits)
            return probs.sample().cpu().numpy()[0]


def make_env(seed, capture_video=True):
    env = gym.make("CarRacing-v2", render_mode="rgb_array", continuous=False)
    env = gym.wrappers.RecordEpisodeStatistics(env)
    if capture_video:
        env = gym.wrappers.RecordVideo(env, logger.video_dir)

    env = CropObservation(env, (84, 96))
    env = gym.wrappers.ResizeObservation(env, (84, 84))
    env = gym.wrappers.GrayScaleObservation(env)
    env = RecordState(env, reset_clean=True)
    env = gym.wrappers.FrameStack(env, 4)
    env.reset(seed=seed)
    env.action_space.seed(seed)
    env.observation_space.seed(seed)
    return env


def run_episode(agent, show_progress=True, capture_video=True, seed=None):
    env = make_env(seed=seed, capture_video=capture_video)
    state, _ = env.reset()
    score = 0
    done = False
    if show_progress:
        progress = tqdm(desc="Score: 0")

    while not done:
        action = agent.select_action(state[-1][np.newaxis, ...])
        state, reward, terminated, truncated, _ = env.step(action)
        score += reward
        done = terminated or truncated
        if show_progress:
            progress.update()
            progress.set_description("Score: {:.2f}".format(score))
    env.close()

    if show_progress:
        progress.close()
    if capture_video:
        show_video(logger.video_dir)

    return score

# %% [markdown]
# ## Evaluate behavioral cloning agent

# %% [markdown]
# Let's see how the agent is doing in the real environment

# %%
train_policy = Agent(model, device)
score = run_episode(train_policy, show_progress=True, capture_video=True);
print(f"Score: {score:.2f}")
# Out:
# Score: 619.33: : 999it [00:29, 39.30it/s]
# Moviepy - Building video /content/data/logdir/2025-03-31T13-43-17/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/data/logdir/2025-03-31T13-43-17/videos/rl-video-episode-0.mp4
# t:   0%|          | 0/1001 [00:00<?, ?it/s, now=None]
# t:   2%|▏         | 21/1001 [00:00<00:05, 176.20it/s, now=None]
# t:   6%|▋         | 64/1001 [00:00<00:03, 298.33it/s, now=None]
# t:   9%|▉         | 95/1001 [00:00<00:08, 103.06it/s, now=None]
# t:  11%|█▏        | 114/1001 [00:01<00:09, 89.59it/s, now=None]
# t:  13%|█▎        | 129/1001 [00:01<00:10, 86.92it/s, now=None]
# t:  14%|█▍        | 141/1001 [00:01<00:09, 90.50it/s, now=None]
# t:  15%|█▌        | 153/1001 [00:01<00:09, 90.97it/s, now=None]
# t:  16%|█▋        | 164/1001 [00:01<00:09, 89.57it/s, now=None]
# t:  17%|█▋        | 175/1001 [00:01<00:08, 92.40it/s, now=None]
# t:  19%|█▊        | 186/1001 [00:01<00:08, 92.08it/s, now=None]
# t:  20%|█▉        | 196/1001 [00:01<00:08, 92.38it/s, now=None]
# t:  21%|██        | 206/1001 [00:02<00:08, 91.83it/s, now=None]
# t:  22%|██▏       | 216/1001 [00:02<00:08, 91.95it/s, now=None]
# t:  23%|██▎       | 226/1001 [00:02<00:08, 92.30it/s, now=None]
# t:  24%|██▎       | 236/1001 [00:02<00:08, 92.29it/s, now=None]
# t:  25%|██▍       | 246/1001 [00:02<00:08, 88.89it/s, now=None]
# t:  25%|██▌       | 255/1001 [00:02<00:09, 77.10it/s, now=None]
# t:  26%|██▋       | 263/1001 [00:02<00:09, 76.38it/s, now=None]
# t:  27%|██▋       | 271/1001 [00:02<00:09, 74.80it/s, now=None]
# t:  28%|██▊       | 279/1001 [00:03<00:10, 69.60it/s, now=None]
# t:  29%|██▊       | 287/1001 [00:03<00:10, 70.72it/s, now=None]
# t:  29%|██▉       | 295/1001 [00:03<00:10, 68.27it/s, now=None]
# t:  30%|███       | 303/1001 [00:03<00:10, 69.43it/s, now=None]
# t:  31%|███       | 312/1001 [00:03<00:09, 73.11it/s, now=None]
# t:  32%|███▏      | 321/1001 [00:03<00:09, 75.54it/s, now=None]
# t:  33%|███▎      | 329/1001 [00:03<00:09, 69.61it/s, now=None]
# t:  34%|███▍      | 338/1001 [00:03<00:09, 71.55it/s, now=None]
# t:  35%|███▍      | 349/1001 [00:03<00:08, 80.68it/s, now=None]
# t:  36%|███▌      | 358/1001 [00:04<00:07, 80.93it/s, now=None]
# t:  37%|███▋      | 370/1001 [00:04<00:06, 91.26it/s, now=None]
# t:  38%|███▊      | 380/1001 [00:04<00:06, 90.55it/s, now=None]
# t:  39%|███▉      | 390/1001 [00:04<00:07, 83.34it/s, now=None]
# t:  40%|███▉      | 400/1001 [00:04<00:06, 86.58it/s, now=None]
# t:  41%|████      | 410/1001 [00:04<00:06, 86.37it/s, now=None]
# t:  42%|████▏     | 420/1001 [00:04<00:06, 89.91it/s, now=None]
# t:  43%|████▎     | 430/1001 [00:04<00:06, 83.09it/s, now=None]
# t:  44%|████▍     | 440/1001 [00:05<00:06, 85.29it/s, now=None]
# t:  45%|████▍     | 449/1001 [00:05<00:06, 83.55it/s, now=None]
# t:  46%|████▌     | 458/1001 [00:05<00:06, 82.09it/s, now=None]
# t:  47%|████▋     | 467/1001 [00:05<00:06, 82.30it/s, now=None]
# t:  48%|████▊     | 476/1001 [00:05<00:06, 83.52it/s, now=None]
# t:  49%|████▊     | 486/1001 [00:05<00:06, 83.99it/s, now=None]
# t:  49%|████▉     | 495/1001 [00:05<00:06, 78.72it/s, now=None]
# t:  51%|█████     | 507/1001 [00:05<00:05, 85.08it/s, now=None]
# t:  52%|█████▏    | 516/1001 [00:05<00:06, 78.14it/s, now=None]
# t:  52%|█████▏    | 524/1001 [00:06<00:06, 73.70it/s, now=None]
# t:  53%|█████▎    | 532/1001 [00:06<00:06, 71.05it/s, now=None]
# t:  54%|█████▍    | 540/1001 [00:06<00:06, 68.40it/s, now=None]
# t:  55%|█████▍    | 547/1001 [00:06<00:07, 64.07it/s, now=None]
# t:  55%|█████▌    | 555/1001 [00:06<00:06, 64.64it/s, now=None]
# t:  56%|█████▌    | 562/1001 [00:06<00:06, 65.99it/s, now=None]
# t:  57%|█████▋    | 573/1001 [00:06<00:05, 76.85it/s, now=None]
# t:  59%|█████▊    | 587/1001 [00:06<00:04, 92.60it/s, now=None]
# t:  60%|█████▉    | 600/1001 [00:06<00:03, 102.74it/s, now=None]
# t:  61%|██████    | 611/1001 [00:07<00:03, 99.59it/s, now=None]
# t:  62%|██████▏   | 622/1001 [00:07<00:03, 102.41it/s, now=None]
# t:  63%|██████▎   | 634/1001 [00:07<00:03, 106.88it/s, now=None]
# t:  65%|██████▍   | 647/1001 [00:07<00:03, 111.25it/s, now=None]
# t:  66%|██████▌   | 659/1001 [00:07<00:03, 112.33it/s, now=None]
# t:  67%|██████▋   | 671/1001 [00:07<00:02, 111.53it/s, now=None]
# t:  68%|██████▊   | 683/1001 [00:07<00:02, 110.08it/s, now=None]
# t:  69%|██████▉   | 695/1001 [00:07<00:02, 109.78it/s, now=None]
# t:  71%|███████   | 707/1001 [00:07<00:02, 110.44it/s, now=None]
# t:  72%|███████▏  | 719/1001 [00:08<00:02, 108.98it/s, now=None]
# t:  73%|███████▎  | 734/1001 [00:08<00:02, 116.98it/s, now=None]
# t:  75%|███████▍  | 748/1001 [00:08<00:02, 122.55it/s, now=None]
# t:  76%|███████▋  | 764/1001 [00:08<00:01, 132.12it/s, now=None]
# t:  78%|███████▊  | 780/1001 [00:08<00:01, 138.80it/s, now=None]
# t:  80%|███████▉  | 796/1001 [00:08<00:01, 143.74it/s, now=None]
# t:  81%|████████  | 811/1001 [00:08<00:01, 145.56it/s, now=None]
# t:  83%|████████▎ | 826/1001 [00:08<00:01, 135.21it/s, now=None]
# t:  84%|████████▍ | 840/1001 [00:08<00:01, 133.54it/s, now=None]
# t:  85%|████████▌ | 854/1001 [00:09<00:01, 130.82it/s, now=None]
# t:  87%|████████▋ | 868/1001 [00:09<00:01, 127.68it/s, now=None]
# t:  88%|████████▊ | 881/1001 [00:09<00:00, 124.88it/s, now=None]
# t:  89%|████████▉ | 894/1001 [00:09<00:00, 119.16it/s, now=None]
# t:  91%|█████████ | 906/1001 [00:09<00:00, 112.59it/s, now=None]
# t:  92%|█████████▏| 918/1001 [00:09<00:00, 111.31it/s, now=None]
# t:  93%|█████████▎| 931/1001 [00:09<00:00, 113.27it/s, now=None]
# t:  94%|█████████▍| 944/1001 [00:09<00:00, 116.49it/s, now=None]
# t:  96%|█████████▌| 957/1001 [00:09<00:00, 118.42it/s, now=None]
# t:  97%|█████████▋| 973/1001 [00:10<00:00, 126.21it/s, now=None]
# Score: 619.33: : 999it [00:40, 39.30it/s]
# t: 100%|█████████▉| 999/1001 [00:10<00:00, 122.50it/s, now=None]
# Score: 619.23: : 1000it [00:40, 24.62it/s]
# Moviepy - Done !
# Moviepy - video ready /content/data/logdir/2025-03-31T13-43-17/videos/rl-video-episode-0.mp4
# <video alt="test" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
# Score: 619.23

# %% [markdown]
# Since we often have high variance when evaluating RL agents we should evaluate the agent multiple times to get a better feeling for its performance.

# %%
train_policy = Agent(model, device)
n_eval_episodes = 10
scores = []
for i in tqdm(range(n_eval_episodes), desc="Episode"):
    scores.append(run_episode(train_policy, show_progress=False, capture_video=False))
    print("Score: %d" % scores[-1])
print("Mean Score: %.2f (Std: %.2f)" %(np.mean(scores), np.std(scores)))
# Out:
# Episode:  10%|█         | 1/10 [00:12<01:52, 12.49s/it]
# Score: 383
# Episode:  20%|██        | 2/10 [00:25<01:41, 12.67s/it]
# Score: 902
# Episode:  30%|███       | 3/10 [00:36<01:25, 12.18s/it]
# Score: 336
# Episode:  40%|████      | 4/10 [00:48<01:10, 11.79s/it]
# Score: 328
# Episode:  50%|█████     | 5/10 [01:01<01:01, 12.24s/it]
# Score: 793
# Episode:  60%|██████    | 6/10 [01:14<00:50, 12.55s/it]
# Score: 567
# Episode:  70%|███████   | 7/10 [01:22<00:33, 11.27s/it]
# Score: 134
# Episode:  80%|████████  | 8/10 [01:33<00:22, 11.08s/it]
# Score: 291
# Episode:  90%|█████████ | 9/10 [01:42<00:10, 10.47s/it]
# Score: 109
# Episode: 100%|██████████| 10/10 [01:55<00:00, 11.56s/it]
# Score: 491
# Mean Score: 433.88 (Std: 246.74)

# %% [markdown]
# # DAGGER

# %% [markdown]
# Now we can implement DAgger, you have downloaded a relatively well trained model you can use as an expert for this purpose.
#
# Load expert model that is provided as ONNX file.

# %% [markdown]
# ## Load the expert

# %%
# Load expert
expert_model = ConvertModel(onnx.load("expert.onnx"))
expert_model = expert_model.to(device)
# Freeze expert weights
for p in expert_model.parameters():
    p.requires_grad = False

expert_policy = Agent(expert_model, device)

# %% [markdown]
# Next, you have to implement the DAgger algorithm (see slides for details). This function implements the core idea of DAgger:
#
#
# 1. Choose the policy with probability beta
# 2. Sample T-step trajectories using this policy
# 3. Label the gathered states with the expert
#
# The aggregation and training part are already implemented.

# %%
# inner loop of DAgger
def dagger(env, train_policy, expert_policy, dataset, beta=1.):
    state, _ = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device)
    #print(f'Shape State:',  np.shape(state)) #Check shape of the state should be: (4, 84, 84)
    N = 200 #dataset.__len__()

    for i in range(N):
        states = env.render() #Get latest state
        if not states:
            print('empty steps')
            continue

        train_state = np.expand_dims(states[-1], 0)
         ## Fix the state shape for expert
        if len(states) >= 4:
            expert_state = states[-4:]
        else:
            expert_state = np.stack([states[-1]] * 4, axis=0)

        # 1) Choose a policy (sample according to beta)
        if random.random() < beta:
            action = expert_policy.select_action(expert_state)
        else:
            with torch.no_grad():
                #print(f'Shape train_state',  np.shape(np.expand_dims(state.cpu()[-1], 0))) # check shape of input should be: (1, 84, 84)
                action = train_policy.select_action(train_state)


        # 2) Sample T-step trajectory with the chosen policy (T can be an entire episode or a single state, think about what makes more sense here and implement it accordingly)
        next_state, reward, terminated, truncated, debug = env.step(action)
        # 3) Label the state (or states) with your expert if they come from your training policy
        label = expert_policy.select_action(state)


        train_tate = train_state.astype(np.float32)
        label = np.array([label], dtype=np.int64)
        dataset.append(train_state, label)

    return dataset




    #### Note ####
    # To get an action for the current state from your training policy or expert policy:
    # action = policy.select_action(state)
    #
    # Your training policy requires a single grayscale state while
    # the expert policy requires four stacked grayscale states
    # You can prepare your state for the policy like so:
    # Train policy:
    # np.expand_dims(state[-1], 0)
    # Expert policy:
    #      state


    # Due to the RecordState wrapper you can get the states from the environment by calling
    # env.render()
    # Doing so will clear the list and the next time you call .render() will return the new states since the last call.
    # Note: be careful with the last state

# %% [markdown]
# Put everything together now.
# 1. Create new samples using the DAgger algorithm
# 2. Continue training your agent
# 3. Export your fully trained agent as an ONNX file

# %%
# Specify the google drive mount here if you want to store logs and weights there (and set it up earlier)
logger = Logger("logdir_dagger")
print("Saving state to {}".format(logger.basepath))

# start environment
env = make_env(seed=42, capture_video=False)

dataset = DemonstrationDataset("train")

# Training
def train_dagger(train_policy, dataset, num_epochs, batch_size, lr, device):

    train_policy = train_policy.model.to(device)
    train_policy.train()
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2, drop_last=True)
    optimizer = torch.optim.AdamW(train_policy.parameters(), lr=lr)
    lossfct = nn.CrossEntropyLoss()

    for epoch in range(num_epochs):
        total_loss = 0
        correct = 0
        total = 0
        for states, actions in dataloader:
            states = states.to(device)
            actions = actions.to(device)

            optimizer.zero_grad()
            prediction = model.forward(states)
            loss = lossfct(prediction, actions)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            pred = prediction.argmax(1)
            correct += (pred == actions).sum().item()
            total += actions.size(0)

        train_loss = total_loss / len(dataloader)
        train_accuracy = correct / total
        logger.log('training_loss', train_loss)
        logger.log('training_entropy', train_accuracy)
        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}")

        #Just write sth into valid logger
        logger.log('validation_loss', 0)
        logger.log('validation_accuracy', 0)

# Train the network
for it in range(10):
  dataset = dagger(env, train_policy, expert_policy, dataset, beta=1.)
  train_dagger(train_policy, dataset, num_epochs=15, batch_size=64, lr=1e-5, device=device)
  plot_metrics(logger)

save_as_onnx(model, sample_state, logger.onnx_file)
env.close()
# Out:
# Saving state to logdir_dagger/2025-03-31T14-12-28
# Epoch [1/15], Train Loss: 0.9170, Train Acc: 0.6512
# Epoch [2/15], Train Loss: 0.9162, Train Acc: 0.6515
# Epoch [3/15], Train Loss: 0.9155, Train Acc: 0.6517
# Epoch [4/15], Train Loss: 0.9150, Train Acc: 0.6518
# Epoch [5/15], Train Loss: 0.9144, Train Acc: 0.6525
# Epoch [6/15], Train Loss: 0.9135, Train Acc: 0.6517
# Epoch [7/15], Train Loss: 0.9130, Train Acc: 0.6526
# Epoch [8/15], Train Loss: 0.9124, Train Acc: 0.6516
# Epoch [9/15], Train Loss: 0.9117, Train Acc: 0.6522
# Epoch [10/15], Train Loss: 0.9113, Train Acc: 0.6526
# Epoch [11/15], Train Loss: 0.9104, Train Acc: 0.6522
# Epoch [12/15], Train Loss: 0.9101, Train Acc: 0.6529
# Epoch [13/15], Train Loss: 0.9096, Train Acc: 0.6524
# Epoch [14/15], Train Loss: 0.9089, Train Acc: 0.6530
# Epoch [15/15], Train Loss: 0.9083, Train Acc: 0.6528
# Epoch [1/15], Train Loss: 0.9123, Train Acc: 0.6514
# Epoch [2/15], Train Loss: 0.9117, Train Acc: 0.6510
# Epoch [3/15], Train Loss: 0.9112, Train Acc: 0.6507
# Epoch [4/15], Train Loss: 0.9108, Train Acc: 0.6512
# Epoch [5/15], Train Loss: 0.9102, Train Acc: 0.6510
# Epoch [6/15], Train Loss: 0.9095, Train Acc: 0.6512
# Epoch [7/15], Train Loss: 0.9089, Train Acc: 0.6513
# Epoch [8/15], Train Loss: 0.9084, Train Acc: 0.6513
# Epoch [9/15], Train Loss: 0.9079, Train Acc: 0.6513
# Epoch [10/15], Train Loss: 0.9075, Train Acc: 0.6515
# Epoch [11/15], Train Loss: 0.9071, Train Acc: 0.6519
# Epoch [12/15], Train Loss: 0.9063, Train Acc: 0.6517
# Epoch [13/15], Train Loss: 0.9059, Train Acc: 0.6521
# Epoch [14/15], Train Loss: 0.9049, Train Acc: 0.6515
# Epoch [15/15], Train Loss: 0.9048, Train Acc: 0.6519
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-84bfa055e711> in <cell line: 0>()
#      49 for it in range(10):
#      50   dataset = dagger(env, train_policy, expert_policy, dataset, beta=1.)
# ---> 51   train_dagger(train_policy, dataset, num_epochs=15, batch_size=64, lr=1e-5, device=device)
#      52   plot_metrics(logger)
#      53
#
# <ipython-input-31-84bfa055e711> in train_dagger(train_policy, dataset, num_epochs, batch_size, lr, device)
#      21         correct = 0
#      22         total = 0
# ---> 23         for states, actions in dataloader:
#      24             states = states.to(device)
#      25             actions = actions.to(device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1456
#    1457             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1458             idx, data = self._get_data()
#    1459             self._tasks_outstanding -= 1
#    1460             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1418         else:
#    1419             while True:
# -> 1420                 success, data = self._try_get_data()
#    1421                 if success:
#    1422                     return data
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1249         #   (bool: whether successfully get data, any: data if successful else None)
#    1250         try:
# -> 1251             data = self._data_queue.get(timeout=timeout)
#    1252             return (True, data)
#    1253         except Exception as e:
#
# /usr/lib/python3.11/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /usr/lib/python3.11/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.11/multiprocessing/connection.py in _poll(self, timeout)
#     438
#     439     def _poll(self, timeout):
# --> 440         r = wait([self], timeout)
#     441         return bool(r)
#     442
#
# /usr/lib/python3.11/multiprocessing/connection.py in wait(object_list, timeout)
#     946
#     947             while True:
# --> 948                 ready = selector.select(timeout)
#     949                 if ready:
#     950                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
save_as_onnx(model, sample_state, logger.onnx_file)
env.close()

# %%
n_eval_episodes = 10
scores = []
for i in tqdm(range(n_eval_episodes), desc="Episode"):
    scores.append(run_episode(train_policy, show_progress=False, capture_video=False))
    print("Score: %d" % scores[-1])
print("Mean Score: %.2f (Std: %.2f)" %(np.mean(scores), np.std(scores)))
# Out:
# Episode:  10%|█         | 1/10 [00:11<01:45, 11.77s/it]
# Score: 573
# Episode:  20%|██        | 2/10 [00:21<01:26, 10.82s/it]
# Score: 761
# Episode:  30%|███       | 3/10 [00:32<01:15, 10.85s/it]
# Score: 589
# Episode:  40%|████      | 4/10 [00:44<01:07, 11.22s/it]
# Score: 663
# Episode:  50%|█████     | 5/10 [00:56<00:57, 11.53s/it]
# Score: 410
# Episode:  60%|██████    | 6/10 [01:08<00:46, 11.57s/it]
# Score: 669
# Episode:  70%|███████   | 7/10 [01:19<00:34, 11.45s/it]
# Score: 389
# Episode:  80%|████████  | 8/10 [01:30<00:22, 11.44s/it]
# Score: 889
# Episode:  90%|█████████ | 9/10 [01:38<00:10, 10.07s/it]
# Score: 198
# Episode: 100%|██████████| 10/10 [01:49<00:00, 10.97s/it]
# Score: 613
# Mean Score: 575.99 (Std: 188.51)
